# %%
# Data Manipulation

import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Data Visualization

import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning

from sklearn.metrics import classification_report
from pycaret.classification import *

# %%
df = pd.read_csv(
    "./data/Crop_recommendation.csv"
)
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %% [markdown]
# # EDA

# %%
df1 = df.copy()

# %% [markdown]
# Data dict : Data fields N - ratio of Nitrogen content in soil P - ratio of Phosphorous content in soil K - ratio of Potassium content in soil temperature - temperature in degree Celsius humidity - relative humidity in % ph - ph value of the soil rainfall - rainfall in mm

# %% [markdown]
# ## Skew analysis

# %%
df1.drop("label", axis=1).skew(axis=0)
# Out:
# N              0.509721
# P              1.010773
# K              2.375167
# temperature    0.184933
# humidity      -1.091708
# ph             0.283929
# rainfall       0.965756
# dtype: float64

# %% [markdown]
# - N → 0,51
#
# Assimetria **positiva moderada**.
# Leve cauda à direita.
#
# - P → 1,01
#
# Assimetria **positiva forte**.
# Tem valores altos puxando a distribuição.
# - K → 2,37
#
# Assimetria **positiva muito forte**.
# Aqui é bem concentrado em valores baixos com poucos valores muito altos.
# Provavelmente precisa transformação (log, por exemplo).
#
# - temperature → 0,18
#
# Quase **simétrica**.
# Distribuição bem comportada.
#
#
# - humidity → -1,09
#
# Assimetria **negativa forte**.
# Cauda longa à esquerda.
# Tem valores baixos puxando a distribuição.
# - ph → 0,28
#
# Leve assimetria positiva.
# Praticamente simétrica.
# - rainfall → 0,97
#
# Assimetria positiva moderada/forte.
# Muitos valores baixos e alguns muito altos.

# %% [markdown]
# ## Nitrogen Distribution

# %%
df1["N"]
# Out:
# 0        90
# 1        85
# 2        60
# 3        74
# 4        78
#        ...
# 2195    107
# 2196     99
# 2197    118
# 2198    117
# 2199    104
# Name: N, Length: 2200, dtype: int64

# %%
import matplotlib.pyplot as plt

# Criando o histograma
plt.hist(df1["N"], bins="auto")

# Títulos e rótulos
plt.title("Nitrogen Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

print(df1["N"].describe())
# Out:
# count    2200.000000
# mean       50.551818
# std        36.917334
# min         0.000000
# 25%        21.000000
# 50%        37.000000
# 75%        84.250000
# max       140.000000
# Name: N, dtype: float64

# %%
df1["N"].quantile(0.6)
# Out:
# 54.0

# %% [markdown]
# - Distribuição assimétrica
# - Desvião padrão alto
# - Apesar da cauda se estender a direita, é possível observar uma tendencia de valores abaixo de 60 aparecerem mais. Isso pode ser confirmado observando o percentil 60

# %%
def analysis(variable, name: str):
    plt.hist(variable, bins="auto")

    # Títulos e rótulos
    plt.title(f"{name} Histogram")
    plt.xlabel("Values")
    plt.ylabel("Frequency")

    plt.show()

    print(variable.describe())

# %% [markdown]
# ## Phosphorous

# %%
analysis(df1["P"], name="Phosphorous")
# Out:
# count    2200.000000
# mean       53.362727
# std        32.985883
# min         5.000000
# 25%        28.000000
# 50%        51.000000
# 75%        68.000000
# max       145.000000
# Name: P, dtype: float64

# %% [markdown]
# - Distribuição assimetrica
# - Alta concentração de valores até 80

# %% [markdown]
# ## Potassium

# %%
analysis(df1["K"], name="Potassium")
# Out:
# count    2200.000000
# mean       48.149091
# std        50.647931
# min         5.000000
# 25%        20.000000
# 50%        32.000000
# 75%        49.000000
# max       205.000000
# Name: K, dtype: float64

# %%
df1["K"].quantile(0.8)
# Out:
# 52.0

# %% [markdown]
# - Assimetria forte!
# - Possível outliers em torno dos valores 200. Análise mais profunda será necessaria
# - Concentração de valores alta até o percentil 80 (até 54)

# %% [markdown]
# ## Label

# %%
df1["label"].describe()
# Out:
# count     2200
# unique      22
# top       rice
# freq       100
# Name: label, dtype: object

# %%
df1["label"].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %% [markdown]
# - Distribuição uniforme. Nada a declarar por enquanto

# %%
plt.figure(figsize=(25, 8))


analysis(df1["label"], name="Label")
# Out:
# count     2200
# unique      22
# top       rice
# freq       100
# Name: label, dtype: object

# %% [markdown]
# ## Analyzing the "nature" variables

# %%
def analysis(data, variable, name: str, log_transformation=False):

    # Gráfico original
    if log_transformation:
        plt.hist(variable, bins="auto")
        plt.title(f"{name} Histogram (Original)")
        plt.xlabel("Values")
        plt.ylabel("Frequency")
        plt.show()

        print(f"Skewness before log: {variable.skew()}")
        print("Original Data:")
        print(variable.describe())

        # Aplicando log
        variable = np.log(variable + 1)
        data[f"{variable.name}_log"] = variable
        data.drop(variable.name, axis=1, inplace=True)

    # Gráfico final (com ou sem log)
    plt.hist(variable, bins="auto")

    if log_transformation:
        plt.title(f"{name} Histogram (Log Transformed)")
    else:
        plt.title(f"{name} Histogram")

    plt.xlabel("Values")
    plt.ylabel("Frequency")
    plt.show()

    print(f"Skewness: {variable.skew()}")
    print("Final Data:")
    print(variable.describe())
    print

# %%
analysis(df1, df1["temperature"], name="Temperature")
# Out:
# Skewness: 0.18493273421137887
# Final Data:
# count    2200.000000
# mean       25.616244
# std         5.063749
# min         8.825675
# 25%        22.769375
# 50%        25.598693
# 75%        28.561654
# max        43.675493
# Name: temperature, dtype: float64

# %% [markdown]
# - Distribuição próxima da normal
# - Por ser proxima do normal os valores tendem a ficar próximo de média. Isso tbm pode ser explicado pois a temperatura geralmente fica em torno da média, apenas mudando por fatores externos como frente fria e até eventos extremos como ciclones e furacões.

# %%
analysis(df1, df1["humidity"], name="humidity", log_transformation=True)
# Out:
# Skewness before log: -1.0917079195808679
# Original Data:
# count    2200.000000
# mean       71.481779
# std        22.263812
# min        14.258040
# 25%        60.261953
# 50%        80.473146
# 75%        89.948771
# max        99.981876
# Name: humidity, dtype: float64
# Skewness: -1.880141804015145
# Final Data:
# count    2200.000000
# mean        4.208081
# std         0.442656
# min         2.725107
# 25%         4.115159
# 50%         4.400273
# 75%         4.510296
# max         4.614941
# Name: humidity, dtype: float64

# %% [markdown]
# - Distribuição com assimetria alta para esquerda mesmo logaritmando
# - Pela cauda ser forte para a esquerda, logaritmar a variável não ajudou a melhorar a assimetria e apenas piorou a assimetria

# %%
analysis(df1, df1["ph"], name="ph", log_transformation=False)
# Out:
# Skewness: 0.2839294375729441
# Final Data:
# count    2200.000000
# mean        6.469480
# std         0.773938
# min         3.504752
# 25%         5.971693
# 50%         6.425045
# 75%         6.923643
# max         9.935091
# Name: ph, dtype: float64

# %% [markdown]
# - Distribuição próxima da normal, o que mostra que os dados giram mais em torno da média 6.46

# %%
analysis(df1, df1["rainfall"], name="rainfall", log_transformation=True)
# Out:
# Skewness before log: 0.9657563536272812
# Original Data:
# count    2200.000000
# mean      103.463655
# std        54.958389
# min        20.211267
# 25%        64.551686
# 50%        94.867624
# 75%       124.267508
# max       298.560117
# Name: rainfall, dtype: float64
# Skewness: -0.30018624278441275
# Final Data:
# count    2200.000000
# mean        4.508730
# std         0.545400
# min         3.054533
# 25%         4.182839
# 50%         4.562968
# 75%         4.830451
# max         5.702315
# Name: rainfall, dtype: float64

# %% [markdown]
# - Distribuição se aproximou da normal após transformação logaritmica, mostrando que os dados logaritmicos tendem a ficar proximos da media, apesar de ter uma cauda levemente pra esquerda

# %%
df1
# Out:
#         N   P   K  temperature        ph   label  humidity_log  rainfall_log
# 0      90  42  43    20.879744  6.502985    rice      4.418874      5.317804
# 1      85  58  41    21.770462  7.038096    rice      4.398388      5.427834
# 2      60  55  44    23.004459  7.840207    rice      4.422698      5.579595
# 3      74  35  40    26.491096  6.980401    rice      4.396402      5.496611
# 4      78  42  42    20.130175  7.628473    rice      4.414069      5.574878
# ...   ...  ..  ..          ...       ...     ...           ...           ...
# 2195  107  34  32    26.774637  6.780064  coffee      4.210842      5.186125
# 2196   99  15  27    27.417112  6.086922  coffee      4.054154      4.859228
# 2197  118  33  30    24.131797  6.362608  coffee      4.222813      5.160909
# 2198  117  32  34    26.272418  6.758793  coffee      3.972693      4.853399
# 2199  104  18  30    23.603016  6.779833  coffee      4.117352      4.955384
#
# [2200 rows x 8 columns]

# %% [markdown]
# ## Correlation analysis

# %%
# Tamanho da figura
plt.figure(figsize=(12, 8))

# Mapa de calor
# Estamos realçando os valores de correlação entre 0.59 e 0.99, positivo ou negativo.
sns.heatmap(
    df1.drop("label", axis=1).corr(),
    annot=True,
    fmt=".2f",
    cmap="Reds",
    vmax=0.99,
    vmin=-0.60,
)
plt.show()

# %% [markdown]
# - Nitrogenio não possui uma correlação forte com a maioria das variaveis, mesmo considerando que faz parte do trio de macronutrientes para plantas
# - P e K possuem uma correlação fortissima. Isso se deve a sua natureza biológica para as plantas, já que "um depende do outro"
# - Temperatura possui uma correlação baixa com a maioria das variaveis, mas apresenta correlação fraca-media com umidade
# - Umidade possui correlação fraca com a maioria, porém apresenta uma correlação fraca-media para temperatura, N e K
# - ph não possui correlações fortes. Comportamento inesperado devido a sua natureza e como importa para P e K
# - rainfall não possui correlação

# %% [markdown]
# Apesar da correlação fortissima entre P + K, não pretendo remover uma ou criar uma nova variável primeiramente, já que essa correlação é natural pro contexto que estamos trabalhando, fora que poderia diminuir interpretabilidade do modelo!

# %%
# Detecting multicolineatiry with VIF


def verifica_vif(train):

    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # Cria o dataframe
    vif = pd.DataFrame()

    # Alimenta cada coluna
    vif["feature"] = train.columns

    # Calcula VIF para cada variável
    vif["VIF"] = [
        variance_inflation_factor(train.values, i) for i in range(len(train.columns))
    ]

    return vif

# %% [markdown]
# Pelas variaveis possuirem escalas diferentes, precisamos padronizar para conseguirmos interpretar melhor o ViF

# %%
scaler = StandardScaler()

df1_scaled = df1.drop("label", axis=1)

df1_scaled = scaler.fit_transform(df1_scaled)

df1_scaled = pd.DataFrame(df1_scaled, columns=scaler.get_feature_names_out())

# %%
df1_scaled
# Out:
#              N         P         K  temperature        ph  humidity_log  \
# 0     1.068797 -0.344551 -0.101688    -0.935587  0.043302      0.476309
# 1     0.933329  0.140616 -0.141185    -0.759646  0.734873      0.430018
# 2     0.255986  0.049647 -0.081939    -0.515898  1.771510      0.484950
# 3     0.635298 -0.556811 -0.160933     0.172807  0.660308      0.425532
# 4     0.743673 -0.344551 -0.121436    -1.083647  1.497868      0.465451
# ...        ...       ...       ...          ...       ...           ...
# 2195  1.529390 -0.587134 -0.318922     0.228814  0.401395      0.006239
# 2196  1.312641 -1.163269 -0.417666     0.355720 -0.494413     -0.347815
# 2197  1.827421 -0.617457 -0.358420    -0.293218 -0.138120      0.033289
# 2198  1.800327 -0.647780 -0.279425     0.129612  0.373904     -0.531885
# 2199  1.448109 -1.072300 -0.358420    -0.397667  0.401096     -0.205011
#
#       rainfall_log
# 0         1.483789
# 1         1.685576
# 2         1.963897
# 3         1.811709
# 4         1.955246
# ...            ...
# 2195      1.242299
# 2196      0.642791
# 2197      1.196054
# 2198      0.632101
# 2199      0.819134
#
# [2200 rows x 7 columns]

# %%
verifica_vif(df1_scaled)
# Out:
#         feature       VIF
# 0             N  1.104347
# 1             P  2.494384
# 2             K  2.570377
# 3   temperature  1.151451
# 4            ph  1.054587
# 5  humidity_log  1.297358
# 6  rainfall_log  1.029208

# %% [markdown]
# - Através do VIF conseguimos saber que não há multicolinearidade entre as nossas variáveis independentes, o que é um bom sinal se caso usarmos algoritmos parametricos

# %% [markdown]
# ## Outliers detection

# %%
def detectar_outliers_iqr(df, coluna):
    Q1 = df[coluna].quantile(0.25)
    Q3 = df[coluna].quantile(0.75)
    IQR = Q3 - Q1

    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers = df[(df[coluna] < limite_inferior) | (df[coluna] > limite_superior)]

    return outliers, limite_inferior, limite_superior


columns = ["N", "P", "K", "temperature", "humidity_log", "ph", "rainfall_log"]

for variables in columns:
    outliers, li, ls = detectar_outliers_iqr(df1, variables)

    print(f"Variable: {variables}")
    print("Limite inferior:", li)
    print("Limite superior:", ls)
    print("Quantidade de outliers:", len(outliers))
    print("\n")
# Out:
# Variable: N
# Limite inferior: -73.875
# Limite superior: 179.125
# Quantidade de outliers: 0
#
#
# Variable: P
# Limite inferior: -32.0
# Limite superior: 128.0
# Quantidade de outliers: 138
#
#
# Variable: K
# Limite inferior: -23.5
# Limite superior: 92.5
# Quantidade de outliers: 200
#
#
# Variable: temperature
# Limite inferior: 14.080955682499999
# Limite superior: 37.2500728825
# Quantidade de outliers: 86
#
#
# Variable: humidity_log
# Limite inferior: 3.522452855794077
# Limite superior: 5.103002469216014
# Quantidade de outliers: 206
#
#
# Variable: ph
# Limite inferior: 4.543768066249998
# Limite superior: 8.351567354250005
# Quantidade de outliers: 57
#
#
# Variable: rainfall_log
# Limite inferior: 3.211420257625638
# Limite superior: 5.801870005081257
# Quantidade de outliers: 42

# %% [markdown]
# Por enquanto não vou remover os outliers.

# %% [markdown]
# # Modeling

# %% [markdown]
# Using pycaret to test different models

# %%
# Since our target variable is categorical and not ordinal, I'm going to use labelencoder()


encoder = LabelEncoder()

y = encoder.fit_transform(df1["label"])
df1_scaled["label"] = y


from sklearn.model_selection import train_test_split

# X = características (features), y = alvo (target)
train, test = train_test_split(df1_scaled, test_size=0.2, random_state=42)

# %%
# Now we have our dataset ready for modeling. We can use PyCaret to quickly compare different classification models and find the best one for our data.

s = setup(df1_scaled, target="label", session_id=123)
# Out:
# <style type="text/css">
# #T_d3412_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d3412">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3412_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d3412_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3412_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3412_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d3412_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3412_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d3412_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3412_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d3412_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3412_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d3412_row3_col1" class="data row3 col1" >(2200, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3412_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d3412_row4_col1" class="data row4 col1" >(2200, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3412_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d3412_row5_col1" class="data row5 col1" >(1540, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d3412_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d3412_row6_col1" class="data row6 col1" >(660, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d3412_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d3412_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d3412_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d3412_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d3412_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d3412_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d3412_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d3412_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d3412_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d3412_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d3412_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d3412_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d3412_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d3412_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d3412_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d3412_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d3412_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d3412_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d3412_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d3412_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d3412_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d3412_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d3412_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d3412_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d3412_row18_col1" class="data row18 col1" >3f79</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_bcbbd th {
#   text-align: left;
# }
# #T_bcbbd_row0_col0, #T_bcbbd_row0_col2, #T_bcbbd_row1_col0, #T_bcbbd_row1_col1, #T_bcbbd_row1_col3, #T_bcbbd_row1_col4, #T_bcbbd_row1_col5, #T_bcbbd_row1_col6, #T_bcbbd_row1_col7, #T_bcbbd_row2_col0, #T_bcbbd_row2_col1, #T_bcbbd_row2_col3, #T_bcbbd_row2_col4, #T_bcbbd_row2_col5, #T_bcbbd_row2_col6, #T_bcbbd_row2_col7, #T_bcbbd_row3_col0, #T_bcbbd_row3_col1, #T_bcbbd_row3_col2, #T_bcbbd_row3_col3, #T_bcbbd_row3_col4, #T_bcbbd_row3_col5, #T_bcbbd_row3_col6, #T_bcbbd_row3_col7, #T_bcbbd_row4_col0, #T_bcbbd_row4_col1, #T_bcbbd_row4_col2, #T_bcbbd_row4_col3, #T_bcbbd_row4_col4, #T_bcbbd_row4_col5, #T_bcbbd_row4_col6, #T_bcbbd_row4_col7, #T_bcbbd_row5_col0, #T_bcbbd_row5_col1, #T_bcbbd_row5_col2, #T_bcbbd_row5_col3, #T_bcbbd_row5_col4, #T_bcbbd_row5_col5, #T_bcbbd_row5_col6, #T_bcbbd_row5_col7, #T_bcbbd_row6_col0, #T_bcbbd_row6_col1, #T_bcbbd_row6_col2, #T_bcbbd_row6_col3, #T_bcbbd_row6_col4, #T_bcbbd_row6_col5, #T_bcbbd_row6_col6, #T_bcbbd_row6_col7, #T_bcbbd_row7_col0, #T_bcbbd_row7_col1, #T_bcbbd_row7_col2, #T_bcbbd_row7_col3, #T_bcbbd_row7_col4, #T_bcbbd_row7_col5, #T_bcbbd_row7_col6, #T_bcbbd_row7_col7, #T_bcbbd_row8_col0, #T_bcbbd_row8_col1, #T_bcbbd_row8_col2, #T_bcbbd_row8_col3, #T_bcbbd_row8_col4, #T_bcbbd_row8_col5, #T_bcbbd_row8_col6, #T_bcbbd_row8_col7, #T_bcbbd_row9_col0, #T_bcbbd_row9_col1, #T_bcbbd_row9_col2, #T_bcbbd_row9_col3, #T_bcbbd_row9_col4, #T_bcbbd_row9_col5, #T_bcbbd_row9_col6, #T_bcbbd_row9_col7, #T_bcbbd_row10_col0, #T_bcbbd_row10_col1, #T_bcbbd_row10_col2, #T_bcbbd_row10_col3, #T_bcbbd_row10_col4, #T_bcbbd_row10_col5, #T_bcbbd_row10_col6, #T_bcbbd_row10_col7, #T_bcbbd_row11_col0, #T_bcbbd_row11_col1, #T_bcbbd_row11_col2, #T_bcbbd_row11_col3, #T_bcbbd_row11_col4, #T_bcbbd_row11_col5, #T_bcbbd_row11_col6, #T_bcbbd_row11_col7, #T_bcbbd_row12_col0, #T_bcbbd_row12_col1, #T_bcbbd_row12_col2, #T_bcbbd_row12_col3, #T_bcbbd_row12_col4, #T_bcbbd_row12_col5, #T_bcbbd_row12_col6, #T_bcbbd_row12_col7, #T_bcbbd_row13_col0, #T_bcbbd_row13_col1, #T_bcbbd_row13_col2, #T_bcbbd_row13_col3, #T_bcbbd_row13_col4, #T_bcbbd_row13_col5, #T_bcbbd_row13_col6, #T_bcbbd_row13_col7 {
#   text-align: left;
# }
# #T_bcbbd_row0_col1, #T_bcbbd_row0_col3, #T_bcbbd_row0_col4, #T_bcbbd_row0_col5, #T_bcbbd_row0_col6, #T_bcbbd_row0_col7, #T_bcbbd_row1_col2, #T_bcbbd_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bcbbd_row0_col8, #T_bcbbd_row1_col8, #T_bcbbd_row2_col8, #T_bcbbd_row3_col8, #T_bcbbd_row4_col8, #T_bcbbd_row5_col8, #T_bcbbd_row6_col8, #T_bcbbd_row7_col8, #T_bcbbd_row8_col8, #T_bcbbd_row9_col8, #T_bcbbd_row10_col8, #T_bcbbd_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bcbbd_row11_col8, #T_bcbbd_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bcbbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcbbd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bcbbd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_bcbbd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_bcbbd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_bcbbd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_bcbbd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_bcbbd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_bcbbd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_bcbbd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcbbd_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_bcbbd_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_bcbbd_row0_col1" class="data row0 col1" >0.9948</td>
#       <td id="T_bcbbd_row0_col2" class="data row0 col2" >0.9999</td>
#       <td id="T_bcbbd_row0_col3" class="data row0 col3" >0.9948</td>
#       <td id="T_bcbbd_row0_col4" class="data row0 col4" >0.9953</td>
#       <td id="T_bcbbd_row0_col5" class="data row0 col5" >0.9948</td>
#       <td id="T_bcbbd_row0_col6" class="data row0 col6" >0.9946</td>
#       <td id="T_bcbbd_row0_col7" class="data row0 col7" >0.9946</td>
#       <td id="T_bcbbd_row0_col8" class="data row0 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_bcbbd_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_bcbbd_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_bcbbd_row1_col1" class="data row1 col1" >0.9929</td>
#       <td id="T_bcbbd_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_bcbbd_row1_col3" class="data row1 col3" >0.9929</td>
#       <td id="T_bcbbd_row1_col4" class="data row1 col4" >0.9937</td>
#       <td id="T_bcbbd_row1_col5" class="data row1 col5" >0.9928</td>
#       <td id="T_bcbbd_row1_col6" class="data row1 col6" >0.9925</td>
#       <td id="T_bcbbd_row1_col7" class="data row1 col7" >0.9926</td>
#       <td id="T_bcbbd_row1_col8" class="data row1 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_bcbbd_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_bcbbd_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_bcbbd_row2_col1" class="data row2 col1" >0.9929</td>
#       <td id="T_bcbbd_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_bcbbd_row2_col3" class="data row2 col3" >0.9929</td>
#       <td id="T_bcbbd_row2_col4" class="data row2 col4" >0.9937</td>
#       <td id="T_bcbbd_row2_col5" class="data row2 col5" >0.9928</td>
#       <td id="T_bcbbd_row2_col6" class="data row2 col6" >0.9925</td>
#       <td id="T_bcbbd_row2_col7" class="data row2 col7" >0.9926</td>
#       <td id="T_bcbbd_row2_col8" class="data row2 col8" >0.0550</td>
#     </tr>
#     <tr>
#       <th id="T_bcbbd_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_bcbbd_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_bcbbd_row3_col1" class="data row3 col1" >0.9922</td>
#       <td id="T_bcbbd_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_bcbbd_row3_col3" class="data row3 col3" >0.9922</td>
#       <td id="T_bcbbd_row3_col4" class="data row3 col4" >0.9933</td>
#       <td id="T_bcbbd_row3_col5" class="data row3 col5" >0.9921</td>
#       <td id="T_bcbbd_row3_col6" class="data row3 col6" >0.9918</td>
#       <td id="T_bcbbd_row3_col7" class="data row3 col7" >0.9919</td>
#       <td id="T_bcbbd_row3_col8" class="data row3 col8" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_bcbbd_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_bcbbd_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_bcbbd_row4_col1" class="data row4 col1" >0.9903</td>
#       <td id="T_bcbbd_row4_col2" class="data row4 col2" >0.9999</td>
#       <td id="T_bcbbd_row4_col3" class="data row4 col3" >0.9903</td>
#       <td id="T_bcbbd_row4_col4" class="data row4 col4" >0.9915</td>
#       <td id="T_bcbbd_row4_col5" class="data row4 col5" >0.9903</td>
#       <td id="T_bcbbd_row4_col6" class="data row4 col6" >0.9898</td>
#       <td id="T_bcbbd_row4_col7" class="data row4 col7" >0.9899</td>
#       <td id="T_bcbbd_row4_col8" class="data row4 col8" >2.8870</td>
#     </tr>
#     <tr>
#       <th id="T_bcbbd_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_bcbbd_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_bcbbd_row5_col1" class="data row5 col1" >0.9883</td>
#       <td id="T_bcbbd_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_bcbbd_row5_col3" class="data row5 col3" >0.9883</td>
#       <td id="T_bcbbd_row5_col4" class="data row5 col4" >0.9897</td>
#       <td id="T_bcbbd_row5_col5" class="data row5 col5" >0.9883</td>
#       <td id="T_bcbbd_row5_col6" class="data row5 col6" >0.9878</td>
#       <td id="T_bcbbd_row5_col7" class="data row5 col7" >0.9878</td>

# %%
predictions = predict_model(best, data=test)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6387c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6387c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6387c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6387c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6387c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6387c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6387c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6387c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6387c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6387c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6387c_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_6387c_row0_col1" class="data row0 col1" >0.9932</td>
#       <td id="T_6387c_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_6387c_row0_col3" class="data row0 col3" >0.9932</td>
#       <td id="T_6387c_row0_col4" class="data row0 col4" >0.9936</td>
#       <td id="T_6387c_row0_col5" class="data row0 col5" >0.9931</td>
#       <td id="T_6387c_row0_col6" class="data row0 col6" >0.9928</td>
#       <td id="T_6387c_row0_col7" class="data row0 col7" >0.9929</td>
#     </tr>
#   </tbody>
# </table>
#              N         P         K  temperature        ph  humidity_log  \
# 1451  1.366828 -1.102623 -0.022693     0.765965 -0.367590      0.798656
# 1334  1.285547 -1.375529  0.056302     0.111228 -0.271588      0.596120
# 1761  0.228893  0.261907  0.016804     3.504974  0.610029      0.765895
# 1735 -0.177513  0.201261  0.135296     1.711417  0.459949      0.697915
# 1576 -0.556825  2.536124  2.998848    -0.533707 -1.119294      0.701593
#
#       rainfall_log  label  prediction_label  prediction_score
# 1451     -2.203549     15                15               1.0
# 1334     -1.078598     21                21               1.0
# 1761      0.445546     17                17               1.0
# 1735      0.168419     17                17               1.0
# 1576      0.505177      0                 0               1.0

# %%
tuned_dt = tune_model(best, optimize="F1", n_iter=50, search_algorithm="random")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:00:23
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_dead0_row10_col0, #T_dead0_row10_col1, #T_dead0_row10_col2, #T_dead0_row10_col3, #T_dead0_row10_col4, #T_dead0_row10_col5, #T_dead0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_dead0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dead0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dead0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dead0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dead0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dead0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dead0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dead0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dead0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dead0_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_dead0_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_dead0_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_dead0_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_dead0_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_dead0_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_dead0_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dead0_row1_col0" class="data row1 col0" >0.9870</td>
#       <td id="T_dead0_row1_col1" class="data row1 col1" >0.9999</td>
#       <td id="T_dead0_row1_col2" class="data row1 col2" >0.9870</td>
#       <td id="T_dead0_row1_col3" class="data row1 col3" >0.9870</td>
#       <td id="T_dead0_row1_col4" class="data row1 col4" >0.9870</td>
#       <td id="T_dead0_row1_col5" class="data row1 col5" >0.9864</td>
#       <td id="T_dead0_row1_col6" class="data row1 col6" >0.9864</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dead0_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_dead0_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_dead0_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_dead0_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_dead0_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_dead0_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_dead0_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dead0_row3_col0" class="data row3 col0" >0.9870</td>
#       <td id="T_dead0_row3_col1" class="data row3 col1" >0.9999</td>
#       <td id="T_dead0_row3_col2" class="data row3 col2" >0.9870</td>
#       <td id="T_dead0_row3_col3" class="data row3 col3" >0.9870</td>
#       <td id="T_dead0_row3_col4" class="data row3 col4" >0.9870</td>
#       <td id="T_dead0_row3_col5" class="data row3 col5" >0.9864</td>
#       <td id="T_dead0_row3_col6" class="data row3 col6" >0.9864</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dead0_row4_col0" class="data row4 col0" >0.9870</td>
#       <td id="T_dead0_row4_col1" class="data row4 col1" >0.9998</td>
#       <td id="T_dead0_row4_col2" class="data row4 col2" >0.9870</td>
#       <td id="T_dead0_row4_col3" class="data row4 col3" >0.9899</td>
#       <td id="T_dead0_row4_col4" class="data row4 col4" >0.9867</td>
#       <td id="T_dead0_row4_col5" class="data row4 col5" >0.9864</td>
#       <td id="T_dead0_row4_col6" class="data row4 col6" >0.9866</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dead0_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_dead0_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_dead0_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_dead0_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_dead0_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_dead0_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_dead0_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dead0_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_dead0_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_dead0_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_dead0_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_dead0_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_dead0_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_dead0_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dead0_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_dead0_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_dead0_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_dead0_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_dead0_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_dead0_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_dead0_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dead0_row8_col0" class="data row8 col0" >0.9870</td>
#       <td id="T_dead0_row8_col1" class="data row8 col1" >0.9997</td>
#       <td id="T_dead0_row8_col2" class="data row8 col2" >0.9870</td>
#       <td id="T_dead0_row8_col3" class="data row8 col3" >0.9886</td>
#       <td id="T_dead0_row8_col4" class="data row8 col4" >0.9869</td>
#       <td id="T_dead0_row8_col5" class="data row8 col5" >0.9864</td>
#       <td id="T_dead0_row8_col6" class="data row8 col6" >0.9865</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dead0_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_dead0_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_dead0_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_dead0_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_dead0_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_dead0_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_dead0_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_dead0_row10_col0" class="data row10 col0" >0.9948</td>
#       <td id="T_dead0_row10_col1" class="data row10 col1" >0.9999</td>
#       <td id="T_dead0_row10_col2" class="data row10 col2" >0.9948</td>
#       <td id="T_dead0_row10_col3" class="data row10 col3" >0.9953</td>
#       <td id="T_dead0_row10_col4" class="data row10 col4" >0.9948</td>
#       <td id="T_dead0_row10_col5" class="data row10 col5" >0.9946</td>
#       <td id="T_dead0_row10_col6" class="data row10 col6" >0.9946</td>
#     </tr>
#     <tr>
#       <th id="T_dead0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_dead0_row11_col0" class="data row11 col0" >0.0064</td>
#       <td id="T_dead0_row11_col1" class="data row11 col1" >0.0001</td>
#       <td id="T_dead0_row11_col2" class="data row11 col2" >0.0064</td>
#       <td id="T_dead0_row11_col3" class="data row11 col3" >0.0059</td>
#       <td id="T_dead0_row11_col4
# Fitting 10 folds for each of 28 candidates, totalling 280 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# Por ser dados augmentados de outros dados, esses dados são perfeitinhos e possuem uma acurácia alta. O propósito do projeto é simular um projeto end-to-end, então a complexidade dos dados não é foco,

# %%
tuned_dt
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Training model

# %% [markdown]
# best

# %%
best
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

# %%
model.fit(train.drop("label", axis=1), train["label"])
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
pred = model.predict(test.drop("label", axis=1))
print(classification_report(test["label"], pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        23
#            1     1.0000    1.0000    1.0000        21
#            2     1.0000    1.0000    1.0000        20
#            3     1.0000    1.0000    1.0000        26
#            4     1.0000    1.0000    1.0000        27
#            5     1.0000    1.0000    1.0000        17
#            6     1.0000    1.0000    1.0000        17
#            7     1.0000    1.0000    1.0000        14
#            8     0.9200    1.0000    0.9583        23
#            9     1.0000    1.0000    1.0000        20
#           10     1.0000    1.0000    1.0000        11
#           11     1.0000    1.0000    1.0000        21
#           12     1.0000    1.0000    1.0000        19
#           13     0.9600    1.0000    0.9796        24
#           14     1.0000    1.0000    1.0000        19
#           15     1.0000    1.0000    1.0000        17
#           16     1.0000    1.0000    1.0000        14
#           17     1.0000    1.0000    1.0000        23
#           18     1.0000    0.9565    0.9778        23
#           19     1.0000    1.0000    1.0000        23
#           20     1.0000    0.8947    0.9444        19
#           21     1.0000    1.0000    1.0000        19
#
#     accuracy                         0.9932       440
#    macro avg     0.9945    0.9932    0.9936       440
# weighted avg     0.9936    0.9932    0.9931       440

# %% [markdown]
# Não vou fazer tuning de parametros pois o modelo já está com uma acurácia quase no máximo e o GaussianNB só possui 2 parametros

# %%
import joblib

preprocessor = {"scaler": scaler, "labelencoder": encoder}

joblib.dump(model, "../model/gaussiannb.joblib")
joblib.dump(preprocessor, "../model/preprocessor.joblib")
# Out:
# ['../model/preprocessor.joblib']
